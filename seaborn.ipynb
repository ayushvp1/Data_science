# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
import seaborn as sns
df = sns.load_dataset("tips")
sns.histplot(df["total_bill"], bins=20, kde=True, color = 'skyblue')
plt.title("Histogram + KDE")
# Out:
# Text(0.5, 1.0, 'Histogram + KDE')

# %%
data = pd.DataFrame({"Category": ['A','B','C','D'],"Value":[4,7,2,9]})
sns.barplot(x="Category",y="Value", data = data)
plt.title("Normal Bar Chart (Seaborn)")
plt.show()

# %%
sns.countplot(x='day', data = df, palette= 'Set2')
plt.title("Count plot")
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_2008\1855807668.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='day', data = df, palette= 'Set2')

# %%
sns.boxplot(x='day', y = 'total_bill', data = df, palette = "pastel")
plt.title("Box Plot")
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_2008\3277646090.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day', y = 'total_bill', data = df, palette = "pastel")

# %%
sns.scatterplot(x='total_bill', y = 'tip', data = df, hue = 'sex', style ='time')
plt.title("Scatter Plot")
plt.show()
